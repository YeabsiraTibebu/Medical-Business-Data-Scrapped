# %%
import numpy as np
import pandas as pd
import category_encoders as ce
import sys, os
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from mpl_toolkits.mplot3d import Axes3D

# %%
sys.path.append(os.path.abspath(os.path.join('../scripts')))
from file_handler import FileHandler
from df_selector import *
from df_cleaner import *
from df_visualizer import *
from app_logger import App_Logger

# %%
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 50)

# %% [markdown]
# # Reading Data

# %%
# create a FileHandler object
file_handler = FileHandler()

# %%
# reading the store csv file
df = file_handler.read_csv("../data/EAHCI.csv")
df.head(10)
# Out:
#                               signature  channel_id channel_name  msg_id  \
# 0  msg_iteration.0.user.EAHCI.post.2163  1432982009        EAHCI    2163
# 1  msg_iteration.1.user.EAHCI.post.2162  1432982009        EAHCI    2162
# 2  msg_iteration.2.user.EAHCI.post.2161  1432982009        EAHCI    2161
# 3  msg_iteration.3.user.EAHCI.post.2160  1432982009        EAHCI    2160
# 4  msg_iteration.4.user.EAHCI.post.2159  1432982009        EAHCI    2159
# 5  msg_iteration.5.user.EAHCI.post.2158  1432982009        EAHCI    2158
# 6  msg_iteration.6.user.EAHCI.post.2157  1432982009        EAHCI    2157
# 7  msg_iteration.7.user.EAHCI.post.2156  1432982009        EAHCI    2156
# 8  msg_iteration.8.user.EAHCI.post.2155  1432982009        EAHCI    2155
# 9  msg_iteration.9.user.EAHCI.post.2154  1432982009        EAHCI    2154
#
#                                              message  \
# 0                                      #For_surgeons
# 1  💥የሞያ ፈቃድ በቅርቡ ለምታሳድሱ💥               \n\n#CPD_(...
# 2                                                NaN
# 3  #💥ሰኞ ይጀምራል እንዳያመልጥዎ💥የግርዛት_ስልጠና_Addis_Ababa & n...
# 4  ✍️Successfully completed OBGYN  Ultrasound  tr...
# 5                                                NaN
# 6  💥#3_ቀን_ቀረው💥የግርዛት_ስልጠና_Addis_Ababa & nekemte\n#...
# 7  💥የሞያ ፈቃድ በቅርቡ ለምታሳድሱ💥               \n\n#CPD_(...
# 8                                                NaN
# 9  #💥የግርዛት_ስልጠና_Addis_Ababa & nekemte\n#Circumcis...
#
#                                      cleaned_message  \
# 0                                      #For_surgeons
# 1  💥የሞያ ፈቃድ በቅርቡ ለምታሳድሱ💥 #CPD_(+Online ) #ሰኔ 10 /...
# 2                                                NaN
# 3  #💥ሰኞ ይጀምራል እንዳያመልጥዎ💥የግርዛት_ስልጠና_Addis_Ababa & n...
# 4  ✍️Successfully completed OBGYN Ultrasound trai...
# 5                                                NaN
# 6  💥#3_ቀን_ቀረው💥የግርዛት_ስልጠና_Addis_Ababa & nekemte #C...
# 7  💥የሞያ ፈቃድ በቅርቡ ለምታሳድሱ💥 #CPD_(+Online ) #ሰኔ 7 /2...
# 8                                                NaN
# 9  #💥የግርዛት_ስልጠና_Addis_Ababa & nekemte #Circumcisi...
#
#                         date                 msg_link  msg_from_peer  \
# 0  2024-06-14 19:06:19+00:00  https://t.me/EAHCI/2163            NaN
# 1  2024-06-14 07:43:30+00:00  https://t.me/EAHCI/2162            NaN
# 2  2024-06-14 07:38:10+00:00  https://t.me/EAHCI/2161            NaN
# 3  2024-06-14 07:38:09+00:00  https://t.me/EAHCI/2160            NaN
# 4  2024-06-13 13:48:07+00:00  https://t.me/EAHCI/2159            NaN
# 5  2024-06-13 08:10:09+00:00  https://t.me/EAHCI/2158            NaN
# 6  2024-06-13 08:10:09+00:00  https://t.me/EAHCI/2157            NaN
# 7  2024-06-12 05:44:23+00:00  https://t.me/EAHCI/2156            NaN
# 8  2024-06-11 17:26:32+00:00  https://t.me/EAHCI/2155            NaN
# 9  2024-06-11 17:26:32+00:00  https://t.me/EAHCI/2154            NaN
#
#    msg_from_id  views  number_replies  number_forwards  is_forward  \
# 0          NaN    195               0                0           0
# 1          NaN   1171               2                8           0
# 2          NaN    702               0                2           0
# 3          NaN    599               0                2           0
# 4          NaN    982               5                1           0
# 5          NaN  11181               0                4           0
# 6          NaN  11022               0                5           0
# 7          NaN   1706               1               14           0
# 8          NaN   2180               0                6           0
# 9          NaN   2082               2                6           0
#
#   forward_msg_from_peer_type  forward_msg_from_peer_id  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# 5                        NaN                       NaN
# 6                        NaN                       NaN
# 7                        NaN                       NaN
# 8                        NaN                       NaN
# 9                        NaN                       NaN
#
#   forward_msg_from_peer_name forward_msg_date forward_msg_date_string  \
# 0                        NaN              NaN                     NaN
# 1                        NaN              NaN                     NaN
# 2                        NaN              NaN                     NaN
# 3                        NaN              NaN                     NaN
# 4                        NaN              NaN                     NaN
# 5                        NaN              NaN                     NaN
# 6                        NaN              NaN                     NaN
# 7                        NaN              NaN                     NaN
# 8                        NaN              NaN                     NaN
# 9                        NaN              NaN                     NaN
#
#   forward_msg_link  is_reply  reply_to_msg_id  reply_msg_link  contains_media  \
# 0              NaN         0              NaN             NaN               1
# 1              NaN         0              NaN             NaN               1
# 2              NaN         0              NaN             NaN               1
# 3              NaN         0              NaN             NaN               1
# 4              NaN         0              NaN             NaN               1
# 5              NaN         0              NaN             NaN               1
# 6              NaN         0              NaN             NaN               1
# 7              NaN         0              NaN             NaN               1
# 8              NaN         0              NaN             NaN               1
# 9              NaN         0              NaN             NaN               1
#
#           media_type  has_url  url domain url_title url_description  \
# 0  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
# 1  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
# 2  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
# 3  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
# 4  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
# 5  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
# 6  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
# 7  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
# 8  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
# 9  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
#
#   document_type  document_id  document_video_duration document_filename  \
# 0           NaN          NaN                      NaN               NaN
# 1           NaN          NaN                      NaN               NaN
# 2           NaN          NaN                      NaN               NaN
# 3           NaN          NaN                      NaN               NaN
# 4           NaN          NaN                      NaN               NaN
# 5           NaN          NaN                      NaN               NaN
# 6           NaN          NaN                      NaN               NaN
# 7           NaN          NaN                      NaN               NaN
# 8           NaN          NaN                      NaN               NaN
# 9           NaN          NaN                      NaN               NaN
#
#    poll_id  poll_question  poll_total_voters  poll_results  \
# 0      NaN            NaN                NaN           NaN
# 1      NaN            NaN                NaN           NaN
# 2      NaN            NaN                NaN           NaN
# 3      NaN            NaN                NaN           NaN
# 4      NaN            NaN                NaN           NaN
# 5      NaN            NaN                NaN           NaN
# 6      NaN            NaN                NaN           NaN
# 7      NaN            NaN                NaN           NaN
# 8      NaN            NaN                NaN           NaN
# 9      NaN            NaN                NaN           NaN
#
#    contact_phone_number  contact_name  contact_userid  geo_type  lat  lng  \
# 0                   NaN           NaN             NaN       NaN  NaN  NaN
# 1                   NaN           NaN             NaN       NaN  NaN  NaN
# 2                   NaN           NaN             NaN       NaN  NaN  NaN
# 3                   NaN           NaN             NaN       NaN  NaN  NaN
# 4                   NaN           NaN             NaN       NaN  NaN  NaN
# 5                   NaN           NaN             NaN       NaN  NaN  NaN
# 6                   NaN           NaN             NaN       NaN  NaN  NaN
# 7                   NaN           NaN             NaN       NaN  NaN  NaN
# 8                   NaN           NaN             NaN       NaN  NaN  NaN
# 9                   NaN           NaN             NaN       NaN  NaN  NaN
#
#    venue_id  venue_type  venue_title  venue_address  venue_provider
# 0       NaN         NaN          NaN            NaN             NaN
# 1       NaN         NaN          NaN            NaN             NaN
# 2       NaN         NaN          NaN            NaN             NaN
# 3       NaN         NaN          NaN            NaN             NaN
# 4       NaN         NaN          NaN            NaN             NaN
# 5       NaN         NaN          NaN            NaN             NaN
# 6       NaN         NaN          NaN            NaN             NaN
# 7       NaN         NaN          NaN            NaN             NaN
# 8       NaN         NaN          NaN            NaN             NaN
# 9       NaN         NaN          NaN            NaN             NaN

# %% [markdown]
# # General Statistics

# %%
df.size
# Out:
# 80556

# %%
df.shape
# Out:
# (1644, 49)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1644 entries, 0 to 1643
# Data columns (total 49 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   signature                   1644 non-null   object
#  1   channel_id                  1644 non-null   int64
#  2   channel_name                1644 non-null   object
#  3   msg_id                      1644 non-null   int64
#  4   message                     1379 non-null   object
#  5   cleaned_message             1379 non-null   object
#  6   date                        1644 non-null   object
#  7   msg_link                    1644 non-null   object
#  8   msg_from_peer               0 non-null      float64
#  9   msg_from_id                 0 non-null      float64
#  10  views                       1644 non-null   int64
#  11  number_replies              1644 non-null   int64
#  12  number_forwards             1644 non-null   int64
#  13  is_forward                  1644 non-null   int64
#  14  forward_msg_from_peer_type  251 non-null    object
#  15  forward_msg_from_peer_id    251 non-null    float64
#  16  forward_msg_from_peer_name  251 non-null    object
#  17  forward_msg_date            258 non-null    object
#  18  forward_msg_date_string     258 non-null    object
#  19  forward_msg_link            251 non-null    object
#  20  is_reply                    1644 non-null   int64
#  21  reply_to_msg_id             0 non-null      float64
#  22  reply_msg_link              0 non-null      float64
#  23  contains_media              1644 non-null   int64
#  24  media_type                  1467 non-null   object
#  25  has_url                     1644 non-null   int64
#  26  url                         113 non-null    object
#  27  domain                      113 non-null    object
#  28  url_title                   113 non-null    object
#  29  url_description             113 non-null    object
#  30  document_type               71 non-null     object
#  31  document_id                 71 non-null     float64
#  32  document_video_duration     11 non-null     float64
#  33  document_filename           60 non-null     object
#  34  poll_id                     0 non-null      float64
#  35  poll_question               0 non-null      float64
#  36  poll_total_voters           0 non-null      float64
#  37  poll_results                0 non-null      float64
#  38  contact_phone_number        0 non-null      float64
#  39  contact_name                0 non-null      float64
#  40  contact_userid              0 non-null      float64
#  41  geo_type                    0 non-null      float64
#  42  lat                         0 non-null      float64
#  43  lng                         0 non-null      float64
#  44  venue_id                    0 non-null      float64
#  45  venue_type                  0 non-null      float64
#  46  venue_title                 0 non-null      float64
#  47  venue_address               0 non-null      float64
#  48  venue_provider              0 non-null      float64
# dtypes: float64(22), int64(9), object(18)
# memory usage: 629.5+ KB

# %% [markdown]
# # Missing Values

# %%
percent_missing_values(df)
# Out:
# The dataset contains 65.51 % missing values.

# %%
missing_df = missing_values_table(df)
# Out:
# Your selected dataframe has 49 columns.
# There are 36 columns that have missing values.

# %%
df = df.dropna(how='all',axis=1)

# %%
df.shape
# Out:
# (1644, 30)

# %%
missing_df
# Out:
#                             Missing Values  % of Total Values    Dtype
# venue_provider                        1644             100.00  float64
# poll_id                               1644             100.00  float64
# poll_question                         1644             100.00  float64
# poll_total_voters                     1644             100.00  float64
# poll_results                          1644             100.00  float64
# contact_phone_number                  1644             100.00  float64
# contact_name                          1644             100.00  float64
# contact_userid                        1644             100.00  float64
# geo_type                              1644             100.00  float64
# reply_msg_link                        1644             100.00  float64
# reply_to_msg_id                       1644             100.00  float64
# lat                                   1644             100.00  float64
# lng                                   1644             100.00  float64
# venue_id                              1644             100.00  float64
# venue_type                            1644             100.00  float64
# venue_title                           1644             100.00  float64
# venue_address                         1644             100.00  float64
# msg_from_id                           1644             100.00  float64
# msg_from_peer                         1644             100.00  float64
# document_video_duration               1633              99.33  float64
# document_filename                     1584              96.35   object
# document_id                           1573              95.68  float64
# document_type                         1573              95.68   object
# url_description                       1531              93.13   object
# url_title                             1531              93.13   object
# domain                                1531              93.13   object
# url                                   1531              93.13   object
# forward_msg_link                      1393              84.73   object
# forward_msg_from_peer_name            1393              84.73   object
# forward_msg_from_peer_id              1393              84.73  float64
# forward_msg_from_peer_type            1393              84.73   object
# forward_msg_date_string               1386              84.31   object
# forward_msg_date                      1386              84.31   object
# cleaned_message                        265              16.12   object
# message                                265              16.12   object
# media_type                             177              10.77   object

# %%
count_missing_rows(df)
# Out:
# 1644 rows(100.0%) contain atleast one missing value.

# %%
# dataframe containing the missing rows for columns in group 1
group1_df = df[df['forward_msg_link'].isna()]
group1_df.head(10)
# Out:
#                               signature  channel_id channel_name  msg_id  \
# 0  msg_iteration.0.user.EAHCI.post.2163  1432982009        EAHCI    2163
# 1  msg_iteration.1.user.EAHCI.post.2162  1432982009        EAHCI    2162
# 2  msg_iteration.2.user.EAHCI.post.2161  1432982009        EAHCI    2161
# 3  msg_iteration.3.user.EAHCI.post.2160  1432982009        EAHCI    2160
# 4  msg_iteration.4.user.EAHCI.post.2159  1432982009        EAHCI    2159
# 5  msg_iteration.5.user.EAHCI.post.2158  1432982009        EAHCI    2158
# 6  msg_iteration.6.user.EAHCI.post.2157  1432982009        EAHCI    2157
# 7  msg_iteration.7.user.EAHCI.post.2156  1432982009        EAHCI    2156
# 8  msg_iteration.8.user.EAHCI.post.2155  1432982009        EAHCI    2155
# 9  msg_iteration.9.user.EAHCI.post.2154  1432982009        EAHCI    2154
#
#                                              message  \
# 0                                      #For_surgeons
# 1  💥የሞያ ፈቃድ በቅርቡ ለምታሳድሱ💥               \n\n#CPD_(...
# 2                                                NaN
# 3  #💥ሰኞ ይጀምራል እንዳያመልጥዎ💥የግርዛት_ስልጠና_Addis_Ababa & n...
# 4  ✍️Successfully completed OBGYN  Ultrasound  tr...
# 5                                                NaN
# 6  💥#3_ቀን_ቀረው💥የግርዛት_ስልጠና_Addis_Ababa & nekemte\n#...
# 7  💥የሞያ ፈቃድ በቅርቡ ለምታሳድሱ💥               \n\n#CPD_(...
# 8                                                NaN
# 9  #💥የግርዛት_ስልጠና_Addis_Ababa & nekemte\n#Circumcis...
#
#                                      cleaned_message  \
# 0                                      #For_surgeons
# 1  💥የሞያ ፈቃድ በቅርቡ ለምታሳድሱ💥 #CPD_(+Online ) #ሰኔ 10 /...
# 2                                                NaN
# 3  #💥ሰኞ ይጀምራል እንዳያመልጥዎ💥የግርዛት_ስልጠና_Addis_Ababa & n...
# 4  ✍️Successfully completed OBGYN Ultrasound trai...
# 5                                                NaN
# 6  💥#3_ቀን_ቀረው💥የግርዛት_ስልጠና_Addis_Ababa & nekemte #C...
# 7  💥የሞያ ፈቃድ በቅርቡ ለምታሳድሱ💥 #CPD_(+Online ) #ሰኔ 7 /2...
# 8                                                NaN
# 9  #💥የግርዛት_ስልጠና_Addis_Ababa & nekemte #Circumcisi...
#
#                         date                 msg_link  views  number_replies  \
# 0  2024-06-14 19:06:19+00:00  https://t.me/EAHCI/2163    195               0
# 1  2024-06-14 07:43:30+00:00  https://t.me/EAHCI/2162   1171               2
# 2  2024-06-14 07:38:10+00:00  https://t.me/EAHCI/2161    702               0
# 3  2024-06-14 07:38:09+00:00  https://t.me/EAHCI/2160    599               0
# 4  2024-06-13 13:48:07+00:00  https://t.me/EAHCI/2159    982               5
# 5  2024-06-13 08:10:09+00:00  https://t.me/EAHCI/2158  11181               0
# 6  2024-06-13 08:10:09+00:00  https://t.me/EAHCI/2157  11022               0
# 7  2024-06-12 05:44:23+00:00  https://t.me/EAHCI/2156   1706               1
# 8  2024-06-11 17:26:32+00:00  https://t.me/EAHCI/2155   2180               0
# 9  2024-06-11 17:26:32+00:00  https://t.me/EAHCI/2154   2082               2
#
#    number_forwards  is_forward forward_msg_from_peer_type  \
# 0                0           0                        NaN
# 1                8           0                        NaN
# 2                2           0                        NaN
# 3                2           0                        NaN
# 4                1           0                        NaN
# 5                4           0                        NaN
# 6                5           0                        NaN
# 7               14           0                        NaN
# 8                6           0                        NaN
# 9                6           0                        NaN
#
#    forward_msg_from_peer_id forward_msg_from_peer_name forward_msg_date  \
# 0                       NaN                        NaN              NaN
# 1                       NaN                        NaN              NaN
# 2                       NaN                        NaN              NaN
# 3                       NaN                        NaN              NaN
# 4                       NaN                        NaN              NaN
# 5                       NaN                        NaN              NaN
# 6                       NaN                        NaN              NaN
# 7                       NaN                        NaN              NaN
# 8                       NaN                        NaN              NaN
# 9                       NaN                        NaN              NaN
#
#   forward_msg_date_string forward_msg_link  is_reply  contains_media  \
# 0                     NaN              NaN         0               1
# 1                     NaN              NaN         0               1
# 2                     NaN              NaN         0               1
# 3                     NaN              NaN         0               1
# 4                     NaN              NaN         0               1
# 5                     NaN              NaN         0               1
# 6                     NaN              NaN         0               1
# 7                     NaN              NaN         0               1
# 8                     NaN              NaN         0               1
# 9                     NaN              NaN         0               1
#
#           media_type  has_url  url domain url_title url_description  \
# 0  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
# 1  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
# 2  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
# 3  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
# 4  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
# 5  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
# 6  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
# 7  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
# 8  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
# 9  MessageMediaPhoto        0  NaN    NaN       NaN             NaN
#
#   document_type  document_id  document_video_duration document_filename
# 0           NaN          NaN                      NaN               NaN
# 1           NaN          NaN                      NaN               NaN
# 2           NaN          NaN                      NaN               NaN
# 3           NaN          NaN                      NaN               NaN
# 4           NaN          NaN                      NaN               NaN
# 5           NaN          NaN                      NaN               NaN
# 6           NaN          NaN                      NaN               NaN
# 7           NaN          NaN                      NaN               NaN
# 8           NaN          NaN                      NaN               NaN
# 9           NaN          NaN                      NaN               NaN

# %%
# all unique values for each column
unique_values_df(group1_df)
# Out:
#                         Column  \
# 0                    signature
# 1                   channel_id
# 2                 channel_name
# 3                       msg_id
# 4                      message
# 5              cleaned_message
# 6                         date
# 7                     msg_link
# 8                        views
# 9               number_replies
# 10             number_forwards
# 11                  is_forward
# 12  forward_msg_from_peer_type
# 13    forward_msg_from_peer_id
# 14  forward_msg_from_peer_name
# 15            forward_msg_date
# 16     forward_msg_date_string
# 17            forward_msg_link
# 18                    is_reply
# 19              contains_media
# 20                  media_type
# 21                     has_url
# 22                         url
# 23                      domain
# 24                   url_title
# 25             url_description
# 26               document_type
# 27                 document_id
# 28     document_video_duration
# 29           document_filename
#
#                                         Unique values
# 0   [msg_iteration.0.user.EAHCI.post.2163, msg_ite...
# 1                                        [1432982009]
# 2                                             [EAHCI]
# 3   [2163, 708, 696, 698, 699, 700, 701, 703, 704,...
# 4   [Basic Obstetrics Ultrasound skill training in...
# 5   [Basic Obstetrics Ultrasound skill training in...
# 6   [2022-09-28 11:23:32+00:00, 2022-09-28 11:22:5...
# 7   [https://t.me/EAHCI/2163, https://t.me/EAHCI/7...
# 8   [3834, 2104, 2550, 2368, 2380, 2490, 3613, 285...
# 9              [0, 1, 2, 3, 4, 5, 8, 6, 7, 9, 10, 13]
# 10  [2, 1, 5, 3, 6, 7, 4, 0, 8, 9, 10, 11, 14, 13,...
# 11                                             [0, 1]
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15  [2023-08-10 05:58:00, 2023-04-13 08:21:29, 202...
# 16  [2023-08-10, 2023-04-13, 2023-01-06, 2022-12-2...
# 17                                                 []
# 18                                                [0]
# 19                                             [1, 0]
# 20  [MessageMediaPhoto, MessageMediaWebPage, Messa...
# 21                                             [0, 1]
# 22  [http://t.me/eahci, https://t.me/EAHCI, https:...
# 23  [t.me, facebook.com, youtu.be, vm.tiktok.com, ...
# 24  [ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEA...
# 25  [Ethio-American CPD Center  & Health consultan...
# 26  [application/pdf, application/vnd.openxmlforma...
# 27  [5.877436782051593e+18, 5.864123508715424e+18,...
# 28             [47.0, 2.127, 2.126, 15.0, 35.0, 60.0]
# 29  [us intro by girum.ppt, seminor on us.pptx, 3r...

# %%
fix_missing_value(df, ['forward_msg_from_peer_type', 'forward_msg_from_peer_id','forward_msg_from_peer_name','forward_msg_date','forward_msg_date_string','forward_msg_link'], 0)
# Out:
# 1393 missing values in the column forward_msg_from_peer_type have been replaced by 0.
# 1393 missing values in the column forward_msg_from_peer_id have been replaced by 0.
# 1393 missing values in the column forward_msg_from_peer_name have been replaced by 0.
# 1386 missing values in the column forward_msg_date have been replaced by 0.
# 1386 missing values in the column forward_msg_date_string have been replaced by 0.
# 1393 missing values in the column forward_msg_link have been replaced by 0.

# %%
fix_missing_value(df, ['url', 'domain','url_title','url_description','document_type','document_id','document_video_duration','document_filename','media_type'], 0)
# Out:
# 1531 missing values in the column url have been replaced by 0.
# 1531 missing values in the column domain have been replaced by 0.
# 1531 missing values in the column url_title have been replaced by 0.
# 1531 missing values in the column url_description have been replaced by 0.
# 1573 missing values in the column document_type have been replaced by 0.
# 1573 missing values in the column document_id have been replaced by 0.
# 1633 missing values in the column document_video_duration have been replaced by 0.
# 1584 missing values in the column document_filename have been replaced by 0.
# 177 missing values in the column media_type have been replaced by 0.

# %%
fix_missing_value(df, ['message', 'cleaned_message'], 0)
# Out:
# 265 missing values in the column message have been replaced by 0.
# 265 missing values in the column cleaned_message have been replaced by 0.

# %%
percent_missing_values(df)
# Out:
# The dataset contains 0.0 % missing values.

# %%
missing_df
# Out:
#                             Missing Values  % of Total Values    Dtype
# venue_provider                        1644             100.00  float64
# poll_id                               1644             100.00  float64
# poll_question                         1644             100.00  float64
# poll_total_voters                     1644             100.00  float64
# poll_results                          1644             100.00  float64
# contact_phone_number                  1644             100.00  float64
# contact_name                          1644             100.00  float64
# contact_userid                        1644             100.00  float64
# geo_type                              1644             100.00  float64
# reply_msg_link                        1644             100.00  float64
# reply_to_msg_id                       1644             100.00  float64
# lat                                   1644             100.00  float64
# lng                                   1644             100.00  float64
# venue_id                              1644             100.00  float64
# venue_type                            1644             100.00  float64
# venue_title                           1644             100.00  float64
# venue_address                         1644             100.00  float64
# msg_from_id                           1644             100.00  float64
# msg_from_peer                         1644             100.00  float64
# document_video_duration               1633              99.33  float64
# document_filename                     1584              96.35   object
# document_id                           1573              95.68  float64
# document_type                         1573              95.68   object
# url_description                       1531              93.13   object
# url_title                             1531              93.13   object
# domain                                1531              93.13   object
# url                                   1531              93.13   object
# forward_msg_link                      1393              84.73   object
# forward_msg_from_peer_name            1393              84.73   object
# forward_msg_from_peer_id              1393              84.73  float64
# forward_msg_from_peer_type            1393              84.73   object
# forward_msg_date_string               1386              84.31   object
# forward_msg_date                      1386              84.31   object
# cleaned_message                        265              16.12   object
# message                                265              16.12   object
# media_type                             177              10.77   object

# %% [markdown]
# # Data Types

# %%
show_cols_mixed_dtypes(df)
# Out:
#                         Column      Data type
# 0                      message  mixed-integer
# 1              cleaned_message  mixed-integer
# 2   forward_msg_from_peer_type  mixed-integer
# 3   forward_msg_from_peer_name  mixed-integer
# 4             forward_msg_date  mixed-integer
# 5      forward_msg_date_string  mixed-integer
# 6             forward_msg_link  mixed-integer
# 7                   media_type  mixed-integer
# 8                          url  mixed-integer
# 9                       domain  mixed-integer
# 10                   url_title  mixed-integer
# 11             url_description  mixed-integer
# 12               document_type  mixed-integer
# 13           document_filename  mixed-integer

# %%
df.dtypes
# Out:
# signature                      object
# channel_id                      int64
# channel_name                   object
# msg_id                          int64
# message                        object
# cleaned_message                object
# date                           object
# msg_link                       object
# views                           int64
# number_replies                  int64
# number_forwards                 int64
# is_forward                      int64
# forward_msg_from_peer_type     object
# forward_msg_from_peer_id      float64
# forward_msg_from_peer_name     object
# forward_msg_date               object
# forward_msg_date_string        object
# forward_msg_link               object
# is_reply                        int64
# contains_media                  int64
# media_type                     object
# has_url                         int64
# url                            object
# domain                         object
# url_title                      object
# url_description                object
# document_type                  object
# document_id                   float64
# document_video_duration       float64
# document_filename              object
# dtype: object

# %%
# get the columns with object data type
string_columns = df.select_dtypes(include='object').columns.tolist()
string_columns
# Out:
# ['signature',
#  'channel_name',
#  'message',
#  'cleaned_message',
#  'date',
#  'msg_link',
#  'forward_msg_from_peer_type',
#  'forward_msg_from_peer_name',
#  'forward_msg_date',
#  'forward_msg_date_string',
#  'forward_msg_link',
#  'media_type',
#  'url',
#  'domain',
#  'url_title',
#  'url_description',
#  'document_type',
#  'document_filename']

# %%
convert_to_string(df, string_columns)

# %%
convert_to_datetime(df, ['date'])

# %%
show_cols_mixed_dtypes(df)
# Out:
# None of the columns contain mixed types.

# %%
df.dtypes
# Out:
# signature                          string[python]
# channel_id                                  int64
# channel_name                       string[python]
# msg_id                                      int64
# message                            string[python]
# cleaned_message                    string[python]
# date                          datetime64[ns, UTC]
# msg_link                           string[python]
# views                                       int64
# number_replies                              int64
# number_forwards                             int64
# is_forward                                  int64
# forward_msg_from_peer_type         string[python]
# forward_msg_from_peer_id                  float64
# forward_msg_from_peer_name         string[python]
# forward_msg_date                   string[python]
# forward_msg_date_string            string[python]
# forward_msg_link                   string[python]
# is_reply                                    int64
# contains_media                              int64
# media_type                         string[python]
# has_url                                     int64
# url                                string[python]
# domain                             string[python]
# url_title                          string[python]
# url_description                    string[python]
# document_type                      string[python]
# document_id                               float64
# document_video_duration                   float64
# document_filename                  string[python]
# dtype: object

# %% [markdown]
# # Duplicates

# %%
# search for duplicate rows and drop them
drop_duplicates(df)
# Out:
# No duplicate rows were found.

# %%
df.duplicated(subset=['signature']).all()
# Out:
# False

# %%
file_handler.to_csv(df, '../data/new/EAHCI.csv')
